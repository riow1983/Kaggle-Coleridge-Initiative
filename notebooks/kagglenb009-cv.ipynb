# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from joblib import Parallel, delayed
from tqdm import tqdm

# %%
import spacy

# %%
df = pd.read_csv("../input/coleridgeinitiative-show-us-the-data/train.csv")
df

# %%
labels = np.sort(df["cleaned_label"].unique())

# %% [markdown]
# ```
# doc1 = nlp("I like salty fries and hamburgers.")
# doc2 = nlp("Fast food tastes very good.")
#
# # Similarity of two documents
# print(doc1, "<->", doc2, doc1.similarity(doc2))
# ```

# %%
def cosim(doc1, doc2):
    """
    Args:
        doc1: str
        doc2: str
    Returns:
        sim: float
    """
    nlp = spacy.load("en_core_web_lg")  # make sure to use larger package!
    # reference: https://github.com/explosion/spaCy/issues/3552
    
    doc1 = nlp(doc1)
    doc2 = nlp(doc2)
    
    sim = doc1.similarity(doc2)
    return sim

# %%
cosim(labels[0], labels[1])

# %% [markdown]
# ```
# dfs = Parallel(n_jobs=-1)(delayed(convert_tokens)(row,
#                                                       i,
#                                                       max_len,
#                                                       train=train,
#                                                       use_pos=use_pos,
#                                                       verbose=verbose) for i,row in tqdm(df.iterrows(), desc="    Converting tokens..."))
# ```

# %%
# outs = []
# for doc1 in tqdm(labels):
#     for doc2 in labels:
#         outs.append(cosim(doc1, doc2))

# %%
'baltimore longitudinal study of aging' in 'baltimore longitudinal study of aging blsa '

# %%
'baltimore longitudinal study of aging blsa ' in 'baltimore longitudinal study of aging'

# %%
outs = []
for doc1 in labels:
    for doc2 in labels:
        outs.append(doc1 in doc2)

# %%
outs = np.array(outs).reshape((len(labels), len(labels)))

# %%
# Mask diagonals
np.fill_diagonal(outs, False)

# %%
# import dictionary for graph
from collections import defaultdict
  
# function for adding edge to graph
graph = defaultdict(list)
def addEdge(graph,u,v):
    graph[u].append(v)

# definition of function
def generate_edges(graph):
    edges = []
  
    # for each node in graph
    for node in graph:
        # for each neighbour node of a single node
        for neighbour in graph[node]:
            # if edge exists then append
            edges.append((node, neighbour))
    return edges

# %%
for i in range(len(labels)):
    u = labels[i]
    vs = labels[outs[i, :]]
#     print("doc:\n", u)
#     print("Similar docs:\n", vs)
#     print()
    for v in vs:
        addEdge(graph, u, v)

# %%
for i,node in enumerate(graph):
    print(i, node)

# %%
edges = generate_edges(graph)

# %%
import networkx as nx
G = nx.Graph()

# %%
#G.add_edges_from([(1, 2), (1, 3)])
G.add_edges_from(edges)

# %%
import matplotlib.pyplot as plt
nx.draw(G, with_labels=True)

# %%
print(len(list(G.nodes)))
list(G.nodes)

# %%
list(G.edges)

# %%
# reference: https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.node_connected_component.html#networkx.algorithms.components.node_connected_component
label = "adni"
try:
    print(" ".join(nx.node_connected_component(G, label)))
except KeyError:
    print(label)

# %%
mycat = dict()
for label in labels:
    try:
        cat = "/".join(nx.node_connected_component(G, label))
        print(f"label: {label},\n cat: {cat}\n")
    except KeyError:
        cat = label
    mycat[label] = cat

# %%
mycat

# %%
len(mycat.keys())

# %%
print(len(set(mycat.values())))
set(mycat.values())

# %%
category

# %%
for cc in nx.connected_components(G):
    print(cc)
    print()

# %%
for ve in edges:
    print(ve)
    print()
    print()

# %%
labels[0]

# %%
outs = Parallel(n_jobs=-1)(delayed(cosim)(doc1, doc2) for doc2 in labels for doc1 in tqdm(labels))

# %%
outs
